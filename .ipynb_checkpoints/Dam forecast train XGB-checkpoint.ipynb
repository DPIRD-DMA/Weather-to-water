# %%
from sklearn.metrics import mean_absolute_error
import seaborn as sns; sns.set_theme(color_codes=True)
from xgboost import XGBRegressor

import pandas as pd
import numpy as np

from datetime import datetime
import pickle
import json
import glob
import os

# %%
# point these at the training and validation csv files
training_data_path = '/home/nick/Documents/Work code/Dam-Forecast/data/dam forecast train.csv'

val_data_path = '/home/nick/Documents/Work code/Dam-Forecast/data/dam forecast val.csv'

# %%
# set location to save model
model_folder = '/mnt/2TB Working/Projects/Dam-Forecast/v4'
model_name = 'dam_forecast_23-11-21.pkl'
model_path = os.path.join(model_folder,model_name)

# %%
# we limit the max dam size as large dams are poorly in our dataset 
max_value = 20000

# %%
# load up training data, do some cleaning
training_data = pd.read_csv(training_data_path)
training_data = training_data.reindex(sorted(training_data.columns), axis=1)
training_data = (training_data[training_data['area'] < max_value])
training_data.head()
# Out:
#    SRC_DATE  acq_date_dec  acq_month  acq_year         area       area_2  \
# 0  20160316   2016.230769          3      2016  1105.433198   153.864004
# 1  20150129   2015.076923          1      2015  3183.203222  1785.069928
# 2  20170115   2017.076923          1      2017  2150.970196   897.691747
# 3  20151122   2015.846154         11      2015  2100.933370  1372.636820
# 4  20160427   2016.307692          4      2016   745.112710   212.889316
#
#    avgt_0_months before  avgt_10_months before  avgt_11_months before  \
# 0             18.827188               9.593542              12.104814
# 1             20.505667              19.087748              21.089087
# 2             23.383415              22.171854              22.709558
# 3             21.770580              24.143391              23.880880
# 4             16.042379               7.387036              10.700971
#
#    avgt_12_months before  ...  rain_12_months before  rain_1_months before  \
# 0              15.134807  ...              23.702415             12.169580
# 1              21.952820  ...              13.548162             17.787035
# 2              23.152836  ...              70.506699             67.542351
# 3              23.421783  ...              19.646500             24.965473
# 4              14.366689  ...              77.476616             43.006248
#
#    rain_2_months before  rain_3_months before  rain_4_months before  \
# 0             39.820667             34.329319             43.577751
# 1             10.376099              1.374129             22.388557
# 2             44.506107             67.854950            148.474075
# 3             13.792111             46.969486             28.507610
# 4             19.020790             80.467728             46.411854
#
#    rain_5_months before  rain_6_months before  rain_7_months before  \
# 0             15.105906             42.618176             39.555309
# 1             21.292080             89.569664            140.160706
# 2            104.649521            114.186661             95.636772
# 3             24.879349             50.769020            196.121002
# 4             56.747665             14.101152             25.388155
#
#    rain_8_months before  rain_9_months before
# 0             85.649841             35.423897
# 1            100.263268             38.794308
# 2            126.187012             22.806345
# 3             29.570827             24.628069
# 4             54.834881             80.665825
#
# [5 rows x 36 columns]

# %%
# load up validation data and to some sorting
val_data = pd.read_csv(val_data_path)
val_data = val_data.reindex(sorted(val_data.columns), axis=1)
val_data = (val_data[val_data['area'] < max_value])
val_data.head()
# Out:
#    SRC_DATE  acq_date_dec  acq_month  acq_year         area       area_2  \
# 0  20151012   2015.769231         10      2015  1467.191148   400.256079
# 1  20160808   2016.615385          8      2016  7575.018970  5781.220903
# 2  20150329   2015.230769          3      2015  2028.126533   581.212166
# 3  20151215   2015.923077         12      2015   569.161178   317.463008
# 4  20160416   2016.307692          4      2016  3367.296500   508.559500
#
#    avgt_0_months before  avgt_10_months before  avgt_11_months before  \
# 0             18.635481              20.496225              18.559628
# 1             16.349541              20.394827              17.614573
# 2             15.383942              12.471212              14.250165
# 3             19.587343              20.264559              19.108833
# 4             19.199778              13.545030              14.191324
#
#    avgt_12_months before  ...  rain_12_months before  rain_1_months before  \
# 0              16.436865  ...              30.197670             20.906387
# 1              16.606274  ...             104.356178             42.576038
# 2              17.330566  ...              20.296410             26.169157
# 3              17.489389  ...              56.603233             51.825485
# 4              18.163313  ...              27.370653             55.944176
#
#    rain_2_months before  rain_3_months before  rain_4_months before  \
# 0             47.989525             31.595964             39.587959
# 1            253.462769             54.635857             63.877918
# 2             61.649181             20.376518             38.139423
# 3              8.417039             51.016552            103.335541
# 4              3.469017             44.472813              4.695564
#
#    rain_5_months before  rain_6_months before  rain_7_months before  \
# 0             28.022364             43.507568             22.958355
# 1            185.935028             84.719727            168.723022
# 2             19.012955             27.550816             38.407516
# 3             90.978836             44.701668            103.889351
# 4             25.031998              3.818929              4.354647
#
#    rain_8_months before  rain_9_months before
# 0              5.184834              3.242137
# 1             55.986111            104.954948
# 2             52.971111             84.799873
# 3             55.203209             72.892220
# 4             73.195625             74.399857
#
# [5 rows x 36 columns]

# %%
# view all training data columns
training_data.columns
# Out:
# Index(['SRC_DATE', 'acq_date_dec', 'acq_month', 'acq_year', 'area', 'area_2',
#        'avgt_0_months before', 'avgt_10_months before',
#        'avgt_11_months before', 'avgt_12_months before',
#        'avgt_1_months before', 'avgt_2_months before', 'avgt_3_months before',
#        'avgt_4_months before', 'avgt_5_months before', 'avgt_6_months before',
#        'avgt_7_months before', 'avgt_8_months before', 'avgt_9_months before',
#        'class', 'class_name', 'file_name', 'geometry', 'rain_0_months before',
#        'rain_10_months before', 'rain_11_months before',
#        'rain_12_months before', 'rain_1_months before', 'rain_2_months before',
#        'rain_3_months before', 'rain_4_months before', 'rain_5_months before',
#        'rain_6_months before', 'rain_7_months before', 'rain_8_months before',
#        'rain_9_months before'],
#       dtype='object')

# %%
# set a list oif columns to drop, the model will not see these
drop_list = ['area_2','file_name', 'SRC_DATE','geometry','acq_year','acq_month','acq_date_dec','class','class_name']

# %%
# remove the drop list and setup target df
train_X = training_data.drop(columns=drop_list)
train_y = training_data[['area_2']]
print(train_y.head())
train_X.head()
# Out:
#         area_2
# 0   153.864004
# 1  1785.069928
# 2   897.691747
# 3  1372.636820
# 4   212.889316
#           area  avgt_0_months before  avgt_10_months before  \
# 0  1105.433198             18.827188               9.593542
# 1  3183.203222             20.505667              19.087748
# 2  2150.970196             23.383415              22.171854
# 3  2100.933370             21.770580              24.143391
# 4   745.112710             16.042379               7.387036
#
#    avgt_11_months before  avgt_12_months before  avgt_1_months before  \
# 0              12.104814              15.134807             19.484682
# 1              21.089087              21.952820             18.338873
# 2              22.709558              23.152836             21.077740
# 3              23.880880              23.421783             19.803915
# 4              10.700971              14.366689             21.675505
#
#    avgt_2_months before  avgt_3_months before  avgt_4_months before  \
# 0             20.001678             20.145357             15.784226
# 1             18.138027             16.920565             14.076387
# 2             16.914667             12.823338             11.581946
# 3             13.919177             11.454651              9.883898
# 4             22.069105             22.534769             22.086338
#
#    avgt_5_months before  ...  rain_12_months before  rain_1_months before  \
# 0             16.346756  ...              23.702415             12.169580
# 1             11.303012  ...              13.548162             17.787035
# 2              9.066343  ...              70.506699             67.542351
# 3             11.013497  ...              19.646500             24.965473
# 4             18.383806  ...              77.476616             43.006248
#
#    rain_2_months before  rain_3_months before  rain_4_months before  \
# 0             39.820667             34.329319             43.577751
# 1             10.376099              1.374129             22.388557
# 2             44.506107             67.854950            148.474075
# 3             13.792111             46.969486             28.507610
# 4             19.020790             80.467728             46.411854
#
#    rain_5_months before  rain_6_months before  rain_7_months before  \
# 0             15.105906             42.618176             39.555309
# 1             21.292080             89.569664            140.160706
# 2            104.649521            114.186661             95.636772
# 3             24.879349             50.769020            196.121002
# 4             56.747665             14.101152             25.388155
#
#    rain_8_months before  rain_9_months before
# 0             85.649841             35.423897
# 1            100.263268             38.794308
# 2            126.187012             22.806345
# 3             29.570827             24.628069
# 4             54.834881             80.665825
#
# [5 rows x 27 columns]

# %%
# setup validation sets
val_X = val_data.drop(columns=drop_list)
val_y = val_data[['area_2']].copy()
print(train_y.head())
print(train_X.shape)
train_X.head()
# Out:
#         area_2
# 0   153.864004
# 1  1785.069928
# 2   897.691747
# 3  1372.636820
# 4   212.889316
# (108847, 27)
#           area  avgt_0_months before  avgt_10_months before  \
# 0  1105.433198             18.827188               9.593542
# 1  3183.203222             20.505667              19.087748
# 2  2150.970196             23.383415              22.171854
# 3  2100.933370             21.770580              24.143391
# 4   745.112710             16.042379               7.387036
#
#    avgt_11_months before  avgt_12_months before  avgt_1_months before  \
# 0              12.104814              15.134807             19.484682
# 1              21.089087              21.952820             18.338873
# 2              22.709558              23.152836             21.077740
# 3              23.880880              23.421783             19.803915
# 4              10.700971              14.366689             21.675505
#
#    avgt_2_months before  avgt_3_months before  avgt_4_months before  \
# 0             20.001678             20.145357             15.784226
# 1             18.138027             16.920565             14.076387
# 2             16.914667             12.823338             11.581946
# 3             13.919177             11.454651              9.883898
# 4             22.069105             22.534769             22.086338
#
#    avgt_5_months before  ...  rain_12_months before  rain_1_months before  \
# 0             16.346756  ...              23.702415             12.169580
# 1             11.303012  ...              13.548162             17.787035
# 2              9.066343  ...              70.506699             67.542351
# 3             11.013497  ...              19.646500             24.965473
# 4             18.383806  ...              77.476616             43.006248
#
#    rain_2_months before  rain_3_months before  rain_4_months before  \
# 0             39.820667             34.329319             43.577751
# 1             10.376099              1.374129             22.388557
# 2             44.506107             67.854950            148.474075
# 3             13.792111             46.969486             28.507610
# 4             19.020790             80.467728             46.411854
#
#    rain_5_months before  rain_6_months before  rain_7_months before  \
# 0             15.105906             42.618176             39.555309
# 1             21.292080             89.569664            140.160706
# 2            104.649521            114.186661             95.636772
# 3             24.879349             50.769020            196.121002
# 4             56.747665             14.101152             25.388155
#
#    rain_8_months before  rain_9_months before
# 0             85.649841             35.423897
# 1            100.263268             38.794308
# 2            126.187012             22.806345
# 3             29.570827             24.628069
# 4             54.834881             80.665825
#
# [5 rows x 27 columns]

# %%
# save out metadata to json, this is usefull when running predictions
meta_dict = {'col_names':list(train_X.columns),
            'model_path':model_path,
            'creation_date':str(datetime.today().strftime('%Y-%m-%d'))}

with open(model_path.replace('.pkl','.json'), 'w') as fp:
    json.dump(meta_dict, fp)

# %%
# train model
reg = XGBRegressor(
    tree_method="hist",
    eval_metric=mean_absolute_error,
)
reg.fit(train_X, train_y, eval_set=[(train_X, train_y)])
# Out:
# [0]	validation_0-rmse:1343.99744
# [1]	validation_0-rmse:1053.65210
# [2]	validation_0-rmse:870.56787
# [3]	validation_0-rmse:758.61902
# [4]	validation_0-rmse:692.55054
# [5]	validation_0-rmse:653.97833
# [6]	validation_0-rmse:630.99390
# [7]	validation_0-rmse:616.05279
# [8]	validation_0-rmse:606.40021
# [9]	validation_0-rmse:599.07886
# [10]	validation_0-rmse:593.31531
# [11]	validation_0-rmse:588.60346
# [12]	validation_0-rmse:583.30743
# [13]	validation_0-rmse:579.48010
# [14]	validation_0-rmse:575.98907
# [15]	validation_0-rmse:572.66211
# [16]	validation_0-rmse:570.77801
# [17]	validation_0-rmse:567.33887
# [18]	validation_0-rmse:564.45209
# [19]	validation_0-rmse:562.53369
# [20]	validation_0-rmse:560.97315
# [21]	validation_0-rmse:558.87445
# [22]	validation_0-rmse:557.02240
# [23]	validation_0-rmse:555.21167
# [24]	validation_0-rmse:551.09821
# [25]	validation_0-rmse:549.62854
# [26]	validation_0-rmse:548.03522
# [27]	validation_0-rmse:545.68494
# [28]	validation_0-rmse:543.94495
# [29]	validation_0-rmse:542.76410
# [30]	validation_0-rmse:539.16956
# [31]	validation_0-rmse:537.67999
# [32]	validation_0-rmse:535.48560
# [33]	validation_0-rmse:534.38721
# [34]	validation_0-rmse:533.10663
# [35]	validation_0-rmse:531.98468
# [36]	validation_0-rmse:530.75031
# [37]	validation_0-rmse:528.90344
# [38]	validation_0-rmse:528.13220
# [39]	validation_0-rmse:526.64185
# [40]	validation_0-rmse:525.50940
# [41]	validation_0-rmse:524.56494
# [42]	validation_0-rmse:523.66242
# [43]	validation_0-rmse:522.58392
# [44]	validation_0-rmse:521.24829
# [45]	validation_0-rmse:519.94128
# [46]	validation_0-rmse:518.33130
# [47]	validation_0-rmse:517.17560
# [48]	validation_0-rmse:515.60260
# [49]	validation_0-rmse:514.00592
# [50]	validation_0-rmse:513.10461
# [51]	validation_0-rmse:511.24084
# [52]	validation_0-rmse:509.78558
# [53]	validation_0-rmse:508.66296
# [54]	validation_0-rmse:507.29129
# [55]	validation_0-rmse:505.12015
# [56]	validation_0-rmse:503.44339
# [57]	validation_0-rmse:501.49222
# [58]	validation_0-rmse:500.18631
# [59]	validation_0-rmse:499.10770
# [60]	validation_0-rmse:498.46579
# [61]	validation_0-rmse:497.78391
# [62]	validation_0-rmse:496.72522
# [63]	validation_0-rmse:496.21033
# [64]	validation_0-rmse:495.24139
# [65]	validation_0-rmse:493.31491
# [66]	validation_0-rmse:492.04392
# [67]	validation_0-rmse:489.42142
# [68]	validation_0-rmse:488.53055
# [69]	validation_0-rmse:487.59460
# [70]	validation_0-rmse:485.86877
# [71]	validation_0-rmse:484.96481
# [72]	validation_0-rmse:483.93851
# [73]	validation_0-rmse:483.56860
# [74]	validation_0-rmse:483.01443
# [75]	validation_0-rmse:482.30679
# [76]	validation_0-rmse:481.18280
# [77]	validation_0-rmse:480.25931
# [78]	validation_0-rmse:478.57553
# [79]	validation_0-rmse:475.89923
# [80]	validation_0-rmse:474.73871
# [81]	validation_0-rmse:474.08890
# [82]	validation_0-rmse:473.53900
# [83]	validation_0-rmse:472.58920
# [84]	validation_0-rmse:471.08560
# [85]	validation_0-rmse:470.37308
# [86]	validation_0-rmse:469.35226
# [87]	validation_0-rmse:468.33606
# [88]	validation_0-rmse:467.43356
# [89]	validation_0-rmse:466.82977
# [90]	validation_0-rmse:465.99585
# [91]	validation_0-rmse:465.57867
# [92]	validation_0-rmse:464.57816
# [93]	validation_0-rmse:464.25922
# [94]	validation_0-rmse:463.65244
# [95]	validation_0-rmse:462.90558
# [96]	validation_0-rmse:461.85614
# [97]	validation_0-rmse:460.91559
# [98]	validation_0-rmse:459.98169
# [99]	validation_0-rmse:458.97562
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1,
#              eval_metric=<function mean_absolute_error at 0x7fdb37e46680>,
#              gamma=0, gpu_id=-1, importance_type='gain',
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=32,
#              num_parallel_tree=1, random_state=0, reg_alpha=0, reg_lambda=1,
#              scale_pos_weight=1, subsample=1, tree_method='hist',
#              validate_parameters=1, verbosity=None)

# %%
# save model to disk
pickle.dump(reg, open(model_path, "wb"))

# %%
# run prediction on validation set
y_pred = reg.predict(val_X)
val_y['preds'] = [value for value in y_pred]

# %%
# plot up validation data preds vs measured values
ax = sns.regplot(x="area_2", y="preds", data=val_y)

# %%
# use numpy to calc the line of best fit equation
np.polyfit(val_y['area_2'], val_y['preds'], 1)
# Out:
# array([  0.83555467, 175.50252883])

# %%
# calc the model error and abs error 
val_y['error'] = val_y['preds']-val_data['area_2']
val_y['abs_error'] = abs(val_y['error'])
val_y.head()
# Out:
#         area_2        preds        error    abs_error
# 0   400.256079   249.299118  -150.956961   150.956961
# 1  5781.220903  4291.352539 -1489.868364  1489.868364
# 2   581.212166   613.013916    31.801750    31.801750
# 3   317.463008   226.914459   -90.548549    90.548549
# 4   508.559500   981.416565   472.857065   472.857065

# %%
# calc the mean abs model error
model_mean_error = val_y['abs_error'].mean()
model_mean_error
# Out:
# 341.96281995618307

# %%
# we can now compare the model to if we had just predicted the mean values for each row
# calc the overall mean from the measured values
mean_value = val_y['area_2'].mean()
# calc the abs distance each row is from the mean
val_y['dist_from_mean'] = abs(val_y['area_2']-mean_value)
# calc the mean distance from the mean, this si comparable to the model_mean_error value above
mean_dist_from_mean = val_y['dist_from_mean'].mean()
mean_dist_from_mean
# Out:
# 885.8515476619473

# %%
# we can now compare the model_mean_error with the mean_dist_from_mean
'The model is explaining '+f"{1-model_mean_error/mean_dist_from_mean:.0%}" +' of the variance'
# Out:
# 'The model is explaining 61% of the variance'
